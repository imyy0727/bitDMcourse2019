# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

from scipy import stats
from scipy.stats import norm, skew

pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %%
df = pd.read_csv('datasets/wine-reviews/winemag-data_first150k.csv')
df.head(5)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points   price        province  \
# 0                     Martha's Vineyard      96 235.000      California
# 1  Carodorum Selección Especial Reserva      96 110.000  Northern Spain
# 2         Special Selected Late Harvest      96  90.000      California
# 3                               Reserve      96  65.000          Oregon
# 4                            La Brûlade      95  66.000        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.drop(df.columns[0], axis=1, inplace=True)
df
# Out:
#             country                                        description  \
# 0                US  This tremendous 100% varietal wine hails from ...
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# ...

# %% [markdown]
# # 数据摘要

# %%
# 不同变量的不同取值的频数
columns = ['country', 'designation', 'province', 'region_1', 'region_2', 'variety', 'winery']
for column in columns:
    print(df[column].value_counts())
    print('-' * 50)
# Out:
# US                        62397
# Italy                     23478
# France                    21098
# Spain                      8268
# Chile                      5816
# Argentina                  5631
# Portugal                   5322
# Australia                  4957
# New Zealand                3320
# Austria                    3057
# Germany                    2452
# South Africa               2258
# Greece                      884
# Israel                      630
# Hungary                     231
# Canada                      196
# Romania                     139
# Slovenia                     94
# Uruguay                      92
# Croatia                      89
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       52
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# ...

# %% [markdown]
# 最大、最小、均值、中位数、四分位数及缺失值的个数

# %%
df.describe()
# Out:
#           points      price
# count 150930.000 137235.000
# mean      87.888     33.131
# std        3.222     36.323
# min       80.000      4.000
# 25%       86.000     16.000
# 50%       88.000     24.000
# 75%       90.000     40.000
# max      100.000   2300.000

# %% [markdown]
# points特征最大值为100，最小值为80，均值为87.88，中位数为88，第一四分位数为86，第三四分位数为90
#
# price特征最大值为2300，最小值为4，均值为33.13，中位数为24，第一四分位数为16，第三四分位数为40

# %%
# 缺失值的个数
df.isnull()[['points', 'price']].sum()
# Out:
# points        0
# price     13695
# dtype: int64

# %% [markdown]
# points缺失值个数为0
#
# price缺失值个数为13695

# %% [markdown]
# # 检验是否服从正态分布
# 由于points的取值是离散值，为每一个取值都加上一个服从正态分布的随机数。因为正态分布的和仍是正态分布，如果points服从正态分布的话，其和也应该服从正态分布。

# %%
points = df['points'].apply(lambda x: x + np.random.normal())
sns.distplot(points, fit=norm);
mu, sigma = norm.fit(points)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=${:.2f}, $\sigma=${:.2f})'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.title('points distribution')

#Q-Q图
fig = plt.figure()
res = stats.probplot(points, plot=plt)
plt.show()
# Out:
#  mu = 87.88 and sigma = 3.37

# %% [markdown]
# 由QQ图可以看出points的分布是正态分布

# %%
price = df['price'].dropna()
price = price.apply(lambda x: x + np.random.normal())
sns.distplot(price, fit=norm);
mu, sigma = norm.fit(price)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=${:.2f}, $\sigma=${:.2f})'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.title('price distribution')

#Q-Q图
fig = plt.figure()
res = stats.probplot(price, plot=plt)
plt.show()
# Out:
#  mu = 33.13 and sigma = 36.33

# %% [markdown]
# 很明显酒的价格是不服从正态分布的

# %%
var = 'points'
data = pd.concat([df['price'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 32))
fig = sns.boxplot(x=var, y="price", data=data)
fig.axis(ymin=0, ymax=2300);

# %% [markdown]
# 经过盒图可以发现，对不同评分的酒来说，价格较低的酒占了绝大部分，价格较高的酒被视为“离群值”。不过这种方法判别出的离群值不是很准确，所以不能够说此盒图中的离群点就是真正的离群值。

# %% [markdown]
# # 填补缺失值

# %% [markdown]
# 首先看一下缺失值占各样本数的比例

# %%
all_data_na = (df.isnull().sum() / len(df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio':all_data_na})
missing_data
# Out:
#              Missing Ratio
# region_2            59.615
# designation         30.302
# region_1            16.604
# price                9.074
# province             0.003
# country              0.003

# %%
fig = plt.figure(figsize=(12, 6))
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data of feature', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data of feature')

# %%
df.isnull().sum()
# Out:
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# 可见，coutry列有5个缺失，designation有45735条缺失，price有13695条缺失，province有5条缺失，region_1有25060条缺失，region_2有89977条缺失。

# %%
df[df['country'].isnull()]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90 17.000      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90 30.000      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81 15.000      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81 15.000      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81 15.000      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %% [markdown]
# 可以发现，country信息缺失的数据同时也缺失province和region_1,region_2数据，对这五条数据直接进行删除

# %%
df.drop(df[df['province'].isnull()].index, inplace=True)

# %%
df[df['designation'].isnull()]
# Out:
#           country                                        description  \
# 36         France  Gingery spice notes accent fresh pear and melo...
# 37          Italy  Aromas of forest floor, violet, red berry and ...
# 38          Italy  This has a charming nose that boasts rose, vio...
# 48          Italy  Ripe dark-skinned berry, forest floor and cook...
# 49             US  The aromas of blue fruit, herbs and spice are ...
# 51         France  This structured, complex Chardonnay is packed ...
# 54             US  There's a lot to like in this nicely priced wh...
# 61      Australia  Moorooduc's estate Pinot Noir is a solid value...
# 64       Portugal  This is a super-ripe, still very young wine. I...
# 71             US  This wine draws from a handful of tremendous v...
# 73             US  Massively fruity, this is an apple/pear bonanz...
# 78             US  This wine over-delivers in quality for the pri...
# 87             US  From a multiplicity of vineyards, this wine wo...
# ...

# %%
df['designation'].value_counts()
# Out:
# Reserve                                    2752
# Reserva                                    1810
# Estate                                     1571
# Barrel sample                              1326
# Riserva                                     754
# Barrel Sample                               639
# Brut                                        624
# Crianza                                     503
# Estate Grown                                449
# Estate Bottled                              396
# Dry                                         374
# Old Vine                                    331
# Gran Reserva                                330
# Brut Rosé                                   248
# Extra Dry                                   244
# Vieilles Vignes                             225
# Bien Nacido Vineyard                        195
# Rosé                                        180
# Late Bottled Vintage                        171
# Réserve                                     166
# ...

# %% [markdown]
# 根据上述信息，发现disignation列没有某一个取值的频率特别高，而此列缺失值的样本数有4万5千多，如果将缺失值填补为出现次数最多的种类，将于真实数据有较大的偏差，所以将缺失值填补为None，代表没有葡萄种类信息。

# %%
df['designation'] = df['designation'].fillna('None')
df.isnull().sum()
# Out:
# country            0
# description        0
# designation        0
# points             0
# price          13695
# province           0
# region_1       25055
# region_2       89972
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# price与points大致成正比，我们将其填补为与其评分相同的其他红酒的平均价钱

# %%
df['price'] = df.groupby('points')['price'].transform(lambda x : x.fillna(x.mean()))
df.isnull().sum()
# Out:
# country            0
# description        0
# designation        0
# points             0
# price              0
# province           0
# region_1       25055
# region_2       89972
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# 将region_1填充为出现频率最高的地点

# %%
df['region_1'].value_counts().index[0]
# Out:
# 'Napa Valley'

# %%
df['region_1'] = df['region_1'].fillna(df['region_1'].value_counts().index[0])

# %%
df.isnull().sum()
# Out:
# country            0
# description        0
# designation        0
# points             0
# price              0
# province           0
# region_1           0
# region_2       89972
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# 根据数据集说明，region_2为nan的代表没有更具体的生产地点，填充为None

# %%
df['region_2'] = df['region_2'].fillna('None')

# %%
all_data_na = (df.isnull().sum() / len(df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio':all_data_na})
missing_data
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# 可见数据集中已经没有了缺失值
